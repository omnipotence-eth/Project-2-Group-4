# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
file_path = 'Resources/Diabetes_Data.csv'
df = pd.read_csv('Resources/Diabetes_Data.csv')

# %%
corr_matrix = df. corr(method='pearson')

# %%
# %config InlineBackend.figure_format = 'retina'

# %%
plt.figure(figsize=(22, 22), dpi=300)
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', vmin=-1, vmax=1)
plt.title('Correlation Matrix Heatmap (Pearson)')
plt.show()

# %%
from sklearn.preprocessing import StandardScaler

# %%
starup_path = 'Resources/Diabetes_Data.csv'
df = pd.read_csv(starup_path)

# %%
features_to_standardize = ['HighChol', 'PhysActivity', 'Fruits', 'Veggies']

# %%
scaler = StandardScaler()

# %%
df[features_to_standardize] = scaler.fit_transform(df[features_to_standardize])
